# %% [markdown]
# ## Synapses
# * https://brian2.readthedocs.io/en/stable/resources/tutorials/2-intro-to-brian-synapses.html

# %%
from brian2 import *
# %matplotlib inline

# %% [markdown]
# ### The simplest synapse

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''
G = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2, 0]
G.tau = [10, 100]*ms

# Comment these two lines out to see what happens without Synapses
S = Synapses(G, G, on_pre='v_post += 0.2') # Synapses are connections between NeuronGroups
# by pre spike, post v increases by 0.2
S.connect(i=0, j=1)

M = StateMonitor(G, 'v', record=True)

run(100*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
xlabel('Time (ms)')
ylabel('v')
legend()

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''
G = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2, 0] # input current
G.tau = [10, 100]*ms

# Comment these two lines out to see what happens without Synapses
#S = Synapses(G, G, on_pre='v_post += 0.2')
#S.connect(i=0, j=1)

M = StateMonitor(G, 'v', record=True)

run(100*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
xlabel('Time (ms)')
ylabel('v')
legend()

# %% [markdown]
# ### Adding a weight

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''
G = NeuronGroup(3, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2, 0, 0]
G.tau = [10, 100, 100]*ms

# Comment these two lines out to see what happens without Synapses
S = Synapses(G, G, 'w : 1', on_pre='v_post += w') # set the weight of the synapse
# define the response of post-synaptic neuron weight by w
S.connect(i=0, j=[1, 2])
S.w = 'j*0.2' # each synapse has a different weight

M = StateMonitor(G, 'v', record=True)

run(50*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
plot(M.t/ms, M.v[2], label='Neuron 2')
xlabel('Time (ms)')
ylabel('v')
legend()

# %% [markdown]
# ### Introducing a delay

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''
G = NeuronGroup(3, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2, 0, 0]
G.tau = [10, 100, 100]*ms

S = Synapses(G, G, 'w : 1', on_pre='v_post += w')
S.connect(i=0, j=[1, 2])
S.w = 'j*0.2'
S.delay = 'j*2*ms' # here we set the delay of the synapse

M = StateMonitor(G, 'v', record=True)

run(50*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
plot(M.t/ms, M.v[2], label='Neuron 2')
xlabel('Time (ms)')
ylabel('v')
legend()

# %% [markdown]
# ### More complex connectivity

# %%
start_scope()

N = 10
G = NeuronGroup(N, 'v:1')
S = Synapses(G, G)
S.connect(condition='i!=j', p=0.2) # we can define the connection by condition and probability

# %%
def visualise_connectivity(S):
    Ns = len(S.source)
    Nt = len(S.target)
    figure(figsize=(10, 4))
    subplot(121)
    plot(zeros(Ns), arange(Ns), 'ok', ms=10)
    plot(ones(Nt), arange(Nt), 'ok', ms=10)
    for i, j in zip(S.i, S.j):
        plot([0, 1], [i, j], '-k')
    xticks([0, 1], ['Source', 'Target'])
    ylabel('Neuron index')
    xlim(-0.1, 1.1)
    ylim(-1, max(Ns, Nt))
    subplot(122)
    plot(S.i, S.j, 'ok')
    xlim(-1, Ns)
    ylim(-1, Nt)
    xlabel('Source neuron index')
    ylabel('Target neuron index')

visualise_connectivity(S)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[10], line 21
#      18     xlabel('Source neuron index')
#      19     ylabel('Target neuron index')
# ---> 21 visualise_connectivity(S)
#
# Cell In[10], line 13, in visualise_connectivity(S)
#      11 ylabel('Neuron index')
#      12 xlim(-0.1, 1.1)
# ---> 13 ylim(-1, max(Ns, Nt))
#      14 subplot(122)
#      15 plot(S.i, S.j, 'ok')
#
# File ~/.conda/envs/brian2/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.conda/envs/brian2/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 10 is out of bounds for array of dimension 0
